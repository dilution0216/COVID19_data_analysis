# %% [markdown]
# ### [Kaggle 데이터셋]
# ---
#
#
# # Data Science for COVID-19 (DS4C)
# ### 캐글 코리아와 함께하는 2nd ML 대회 - House Price Prediction

# %% [markdown]
# - 링크 : https://www.kaggle.com/kimjihoo/coronavirusdataset

# %% [markdown]
# ### 지도 데이터 커널
# - https://www.kaggle.com/mbnb8317/ds4c-tutorial-all-about-folium

# %% [markdown]
# ### Import Modules

# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load Dataset

# %%
patient_info = pd.read_csv("./coronavirusdataset/PatientInfo.csv", index_col="patient_id")
print(patient_info.shape)
patient_info.head()
# Out:
# (3253, 17)
#             global_num     sex  birth_year  age country province         city  \
# patient_id
# 1000000001         2.0    male      1964.0  50s   Korea    Seoul   Gangseo-gu
# 1000000002         5.0    male      1987.0  30s   Korea    Seoul  Jungnang-gu
# 1000000003         6.0    male      1964.0  50s   Korea    Seoul    Jongno-gu
# 1000000004         7.0    male      1991.0  20s   Korea    Seoul      Mapo-gu
# 1000000005         9.0  female      1992.0  20s   Korea    Seoul  Seongbuk-gu
#
#            disease        infection_case  infection_order   infected_by  \
# patient_id
# 1000000001     NaN       overseas inflow              1.0           NaN
# 1000000002     NaN       overseas inflow              1.0           NaN
# 1000000003     NaN  contact with patient              2.0  2.002000e+09
# 1000000004     NaN       overseas inflow              1.0           NaN
# 1000000005     NaN  contact with patient              2.0  1.000000e+09
#
# ...

# %%
patient_route = pd.read_csv("./coronavirusdataset/PatientRoute.csv")
print(patient_route.shape)
patient_route.head()
# Out:
# (5321, 8)
#    patient_id  global_num        date     province          city  \
# 0  1000000001         2.0  2020-01-22  Gyeonggi-do      Gimpo-si
# 1  1000000001         2.0  2020-01-24        Seoul       Jung-gu
# 2  1000000002         5.0  2020-01-25        Seoul   Seongbuk-gu
# 3  1000000002         5.0  2020-01-26        Seoul   Seongbuk-gu
# 4  1000000002         5.0  2020-01-26        Seoul  Seongdong-gu
#
#                     type   latitude   longitude
# 0                airport  37.615246  126.715632
# 1               hospital  37.567241  127.005659
# 2                    etc  37.592560  127.017048
# 3                  store  37.591810  127.016822
# 4  public_transportation  37.563992  127.029534
